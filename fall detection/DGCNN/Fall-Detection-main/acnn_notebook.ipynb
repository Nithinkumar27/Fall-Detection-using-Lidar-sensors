# %%
import os
import pandas as pd

def label_dataset(file_name):
    # Determine the label based on the file name
    if "falling" in file_name or "Falling" in file_name:
        return "falling"
    elif "lying_down" in file_name or "Lying" in file_name:
        return "lying_down"
    elif "sitting" in file_name:
        return "sitting"
    elif "standing" in file_name:
        return "standing"
    elif "walking_fall2" in file_name:
        return "walking"
    else:
        return None

def main(input_directory, output_file):
    all_data = []
    
    # Iterate over all files in the specified directory
    for file_name in os.listdir(input_directory):
        if file_name.endswith(".csv"):
            # Load the dataset
            df = pd.read_csv(os.path.join(input_directory, file_name), header=None, names=["X", "Y", "Z"])
            
            # Label the dataset
            label = label_dataset(file_name)
            if label:
                df["label"] = label
                all_data.append(df)
            else:
                print(f"Warning: {file_name} does not match any predefined categories. Skipping.")
    
    # Combine all labeled datasets
    combined_df = pd.concat(all_data, ignore_index=True)
    
    # Save the combined dataset to the output file
    combined_df.to_csv(output_file, index=False)
    print(f"Combined dataset saved to {output_file}")

if __name__ == "__main__":
    # Specify the directory containing your CSV files and the output file name
    input_directory = r"C:\Users\imnit\Downloads\annotationfinal\annotation\standing"
    output_file = "standing_combined_labeled_data.csv"
    
    main(input_directory, output_file)
# Out:
# Combined dataset saved to standing_combined_labeled_data.csv

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split

def filter_numeric_rows(df):
    """Keep only rows with numeric values in columns X, Y, Z."""
    return df[pd.to_numeric(df['X'], errors='coerce').notnull()]

def normalize_point_cloud(point_cloud_df):
    """Normalize the XYZ coordinates of a point cloud."""
    xyz = point_cloud_df[['X', 'Y', 'Z']].values
    centroid = xyz.mean(axis=0)
    xyz -= centroid
    furthest_distance = max((xyz**2).sum(axis=1)**0.5)
    xyz /= furthest_distance
    point_cloud_df[['X', 'Y', 'Z']] = xyz
    return point_cloud_df

def main(datasets, output_directory):
    # Load, filter, and normalize datasets
    filtered_dataframes = {category: filter_numeric_rows(pd.read_csv(path, names=['X', 'Y', 'Z', 'label'])) for category, path in datasets.items()}
    for category, df in filtered_dataframes.items():
        df[['X', 'Y', 'Z']] = df[['X', 'Y', 'Z']].astype(float)
        df = normalize_point_cloud(df)
        df.to_csv(os.path.join(output_directory, f'{category}_normalized.csv'), index=False)
    
    # Combine all datasets
    combined_normalized_df = pd.concat(filtered_dataframes.values(), ignore_index=True)
    
    # Split the data
    train_df, temp_df = train_test_split(combined_normalized_df, test_size=0.2, random_state=42, stratify=combined_normalized_df['label'])
    val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42, stratify=temp_df['label'])
    
    # Save the resulting datasets
    train_df.to_csv(os.path.join(output_directory, 'train_data.csv'), index=False)
    val_df.to_csv(os.path.join(output_directory, 'val_data.csv'), index=False)
    test_df.to_csv(os.path.join(output_directory, 'test_data.csv'), index=False)

if __name__ == '__main__':
    # Specify the datasets and the output directory
    datasets = {
        'falling': r'C:\Users\imnit\OneDrive\Desktop\EDA\falling_combined_labeled_data.csv',
        'lying_down': r'C:\Users\imnit\OneDrive\Desktop\EDA\lying_down_combined_labeled_data.csv',
        'sitting': r'C:\Users\imnit\OneDrive\Desktop\EDA\sitting_combined_labeled_data.csv',
        'standing': r'C:\Users\imnit\OneDrive\Desktop\EDA\standing_combined_labeled_data.csv'
    }
    output_directory = r"C:\Users\imnit\OneDrive\Desktop\EDA"
    
    main(datasets, output_directory)

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder

# Load datasets
def load_data(file_path):
    df = pd.read_csv(file_path)
    X = df[['X', 'Y', 'Z']].values
    y = df['label'].values
    return X, y

train_X, train_y = load_data(r"C:\Users\imnit\OneDrive\Desktop\eda\train_data.csv")
val_X, val_y = load_data(r"C:\Users\imnit\OneDrive\Desktop\eda\val_data.csv")
test_X, test_y = load_data(r"C:\Users\imnit\OneDrive\Desktop\eda\test_data.csv")

# Convert labels to integer values
encoder = LabelEncoder()
train_y = encoder.fit_transform(train_y)
val_y = encoder.transform(val_y)
test_y = encoder.transform(test_y)

# Model definition
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(3,)),  # Input layer
    tf.keras.layers.Dense(128, activation='relu'),                   # Hidden layer
    tf.keras.layers.Dense(5, activation='softmax')                   # Output layer
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(train_X, train_y, validation_data=(val_X, val_y), epochs=64, batch_size=32)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(test_X, test_y)
print(f"Test accuracy: {test_accuracy * 100:.2f}%")

# Save the model
model.save(r"C:\Users\imnit\OneDrive\Desktop\EDA\acnn_model")
# Out:
# Epoch 1/64
# 10762/10762 [==============================] - 17s 2ms/step - loss: 0.7834 - accuracy: 0.6765 - val_loss: 0.7112 - val_accuracy: 0.7022
# Epoch 2/64
# 10762/10762 [==============================] - 16s 2ms/step - loss: 0.6554 - accuracy: 0.7289 - val_loss: 0.6329 - val_accuracy: 0.7349
# Epoch 3/64
# 10762/10762 [==============================] - 16s 2ms/step - loss: 0.6188 - accuracy: 0.7457 - val_loss: 0.6081 - val_accuracy: 0.7468
# Epoch 4/64
# 10762/10762 [==============================] - 17s 2ms/step - loss: 0.5982 - accuracy: 0.7553 - val_loss: 0.5722 - val_accuracy: 0.7648
# Epoch 5/64
# 10762/10762 [==============================] - 21s 2ms/step - loss: 0.5821 - accuracy: 0.7614 - val_loss: 0.5639 - val_accuracy: 0.7683
# Epoch 6/64
# 10762/10762 [==============================] - 22s 2ms/step - loss: 0.5680 - accuracy: 0.7669 - val_loss: 0.5497 - val_accuracy: 0.7749
# Epoch 7/64
# 10762/10762 [==============================] - 22s 2ms/step - loss: 0.5547 - accuracy: 0.7740 - val_loss: 0.5540 - val_accuracy: 0.7779
# Epoch 8/64
# 10762/10762 [==============================] - 24s 2ms/step - loss: 0.5444 - accuracy: 0.7791 - val_loss: 0.5228 - val_accuracy: 0.7918
# Epoch 9/64
# 10762/10762 [==============================] - 20s 2ms/step - loss: 0.5335 - accuracy: 0.7839 - val_loss: 0.5177 - val_accuracy: 0.7884
# Epoch 10/64
# 10762/10762 [==============================] - 19s 2ms/step - loss: 0.5239 - accuracy: 0.7884 - val_loss: 0.5132 - val_accuracy: 0.7890
# Epoch 11/64
# 10762/10762 [==============================] - 18s 2ms/step - loss: 0.5145 - accuracy: 0.7934 - val_loss: 0.5063 - val_accuracy: 0.7959
# Epoch 12/64
# 10762/10762 [==============================] - 18s 2ms/step - loss: 0.5065 - accuracy: 0.7974 - val_loss: 0.5054 - val_accuracy: 0.7977
# Epoch 13/64
# 10762/10762 [==============================] - 16s 2ms/step - loss: 0.4986 - accuracy: 0.8013 - val_loss: 0.4955 - val_accuracy: 0.8024
# Epoch 14/64
# 10762/10762 [==============================] - 17s 2ms/step - loss: 0.4911 - accuracy: 0.8048 - val_loss: 0.4732 - val_accuracy: 0.8128
# Epoch 15/64
# 10762/10762 [==============================] - 16s 2ms/step - loss: 0.4834 - accuracy: 0.8080 - val_loss: 0.4720 - val_accuracy: 0.8101
# Epoch 16/64
# 10762/10762 [==============================] - 17s 2ms/step - loss: 0.4761 - accuracy: 0.8119 - val_loss: 0.4733 - val_accuracy: 0.8130
# Epoch 17/64
# 10762/10762 [==============================] - 17s 2ms/step - loss: 0.4680 - accuracy: 0.8156 - val_loss: 0.4618 - val_accuracy: 0.8235
# Epoch 18/64
# 10762/10762 [==============================] - 17s 2ms/step - loss: 0.4620 - accuracy: 0.8190 - val_loss: 0.4643 - val_accuracy: 0.8121
# Epoch 19/64
# 10762/10762 [==============================] - 17s 2ms/step - loss: 0.4546 - accuracy: 0.8217 - val_loss: 0.4466 - val_accuracy: 0.8226
# Epoch 20/64
# 10762/10762 [==============================] - 17s 2ms/step - loss: 0.4473 - accuracy: 0.8260 - val_loss: 0.4547 - val_accuracy: 0.8294
# Epoch 21/64
# 10762/10762 [==============================] - 17s 2ms/step - loss: 0.4410 - accuracy: 0.8295 - val_loss: 0.4301 - val_accuracy: 0.8378
# Epoch 22/64
# 10762/10762 [==============================] - 19s 2ms/step - loss: 0.4347 - accuracy: 0.8329 - val_loss: 0.4253 - val_accuracy: 0.8359
# Epoch 23/64
# 10762/10762 [==============================] - 21s 2ms/step - loss: 0.4285 - accuracy: 0.8358 - val_loss: 0.4220 - val_accuracy: 0.8416
# Epoch 24/64
# 10762/10762 [==============================] - 18s 2ms/step - loss: 0.4222 - accuracy: 0.8388 - val_loss: 0.4221 - val_accuracy: 0.8430
# Epoch 25/64
# 10762/10762 [==============================] - 18s 2ms/step - loss: 0.4161 - accuracy: 0.8418 - val_loss: 0.4088 - val_accuracy: 0.8458
# Epoch 26/64
# 10762/10762 [==============================] - 18s 2ms/step - loss: 0.4109 - accuracy: 0.8437 - val_loss: 0.4202 - val_accuracy: 0.8351
# Epoch 27/64
# 10762/10762 [==============================] - 19s 2ms/step - loss: 0.4053 - accuracy: 0.8464 - val_loss: 0.3950 - val_accuracy: 0.8526
# Epoch 28/64
# 10762/10762 [==============================] - 19s 2ms/step - loss: 0.4004 - accuracy: 0.8480 - val_loss: 0.4318 - val_accuracy: 0.8307
# Epoch 29/64
# 10762/10762 [==============================] - 18s 2ms/step - loss: 0.3964 - accuracy: 0.8500 - val_loss: 0.4005 - val_accuracy: 0.8467
# Epoch 30/64
# 10762/10762 [==============================] - 17s 2ms/step - loss: 0.3917 - accuracy: 0.8509 - val_loss: 0.3837 - val_accuracy: 0.8566
# Epoch 31/64
# 10762/10762 [==============================] - 17s 2ms/step - loss: 0.3876 - accuracy: 0.8526 - val_loss: 0.4022 - val_accuracy: 0.8408
# Epoch 32/64
# 10762/10762 [==============================] - 16s 2ms/step - loss: 0.3841 - accuracy: 0.8539 - val_loss: 0.3839 - val_accuracy: 0.8515
# Epoch 33/64
# 10762/10762 [==============================] - 17s 2ms/step - loss: 0.3811 - accuracy: 0.8549 - val_loss: 0.3703 - val_accuracy: 0.8601
# Epoch 34/64
# 10762/10762 [==============================] - 18s 2ms/step - loss: 0.3770 - accuracy: 0.8568 - val_loss: 0.3772 - val_accuracy: 0.8579
# Epoch 35/64
# 10762/10762 [==============================] - 18s 2ms/step - loss: 0.3743 - accuracy: 0.8577 - val_loss: 0.3729 - val_accuracy: 0.8613
# Epoch 36/64
# 10762/10762 [==============================] - 18s 2ms/step - loss: 0.3711 - accuracy: 0.8589 - val_loss: 0.3791 - val_accuracy: 0.8549
# Epoch 37/64
# 10762/10762 [==============================] - 17s 2ms/step - loss: 0.3685 - accuracy: 0.8602 - val_loss: 0.3650 - val_accuracy: 0.8634
# Epoch 38/64
# 10762/10762 [==============================] - 17s 2ms/step - loss: 0.3650 - accuracy: 0.8612 - val_loss: 0.3670 - val_accuracy: 0.8610
# Epoch 39/64
# 10762/10762 [==============================] - 17s 2ms/step - loss: 0.3617 - accuracy: 0.8623 - val_loss: 0.3668 - val_accuracy: 0.8627
# Epoch 40/64
# 10762/10762 [==============================] - 18s 2ms/step - loss: 0.3590 - accuracy: 0.8628 - val_loss: 0.3493 - val_accuracy: 0.8710
# Epoch 41/64
# 10762/10762 [==============================] - 19s 2ms/step - loss: 0.3555 - accuracy: 0.8645 - val_loss: 0.3565 - val_accuracy: 0.8663
# Epoch 42/64
# 10762/10762 [==============================] - 18s 2ms/step - loss: 0.3546 - accuracy: 0.8655 - val_loss: 0.3466 - val_accuracy: 0.8702
# Epoch 43/64
# 10762/10762 [==============================] - 18s 2ms/step - loss: 0.3506 - accuracy: 0.8669 - val_loss: 0.3431 - val_accuracy: 0.8711
# Epoch 44/64
# 10762/10762 [==============================] - 17s 2ms/step - loss: 0.3476 - accuracy: 0.8677 - val_loss: 0.3535 - val_accuracy: 0.8689
# Epoch 45/64
# 10762/10762 [==============================] - 18s 2ms/step - loss: 0.3448 - accuracy: 0.8687 - val_loss: 0.3371 - val_accuracy: 0.8747
# Epoch 46/64
# 10762/10762 [==============================] - 18s 2ms/step - loss: 0.3428 - accuracy: 0.8700 - val_loss: 0.3489 - val_accuracy: 0.8725
# Epoch 47/64
# 10762/10762 [==============================] - 18s 2ms/step - loss: 0.3398 - accuracy: 0.8710 - val_loss: 0.3486 - val_accuracy: 0.8683
# Epoch 48/64
# 10762/10762 [==============================] - 18s 2ms/step - loss: 0.3380 - accuracy: 0.8713 - val_loss: 0.3528 - val_accuracy: 0.8691
# Epoch 49/64
# 10762/10762 [==============================] - 23s 2ms/step - loss: 0.3351 - accuracy: 0.8728 - val_loss: 0.3333 - val_accuracy: 0.8729
# Epoch 50/64
# 10762/10762 [==============================] - 42s 4ms/step - loss: 0.3328 - accuracy: 0.8730 - val_loss: 0.3544 - val_accuracy: 0.8659
# Epoch 51/64
# 10762/10762 [==============================] - 36s 3ms/step - loss: 0.3299 - accuracy: 0.8747 - val_loss: 0.3270 - val_accuracy: 0.8740
# Epoch 52/64
# 10762/10762 [==============================] - 36s 3ms/step - loss: 0.3279 - accuracy: 0.8749 - val_loss: 0.3186 - val_accuracy: 0.8805
# Epoch 53/64
# 10762/10762 [==============================] - 36s 3ms/step - loss: 0.3261 - accuracy: 0.8756 - val_loss: 0.3224 - val_accuracy: 0.8774
# Epoch 54/64
# 10762/10762 [==============================] - 39s 4ms/step - loss: 0.3236 - accuracy: 0.8767 - val_loss: 0.3267 - val_accuracy: 0.8774
# Epoch 55/64
# 10762/10762 [==============================] - 34s 3ms/step - loss: 0.3210 - accuracy: 0.8773 - val_loss: 0.3079 - val_accuracy: 0.8820
# Epoch 56/64
# 10762/10762 [==============================] - 35s 3ms/step - loss: 0.3191 - accuracy: 0.8782 - val_loss: 0.3044 - val_accuracy: 0.8858
# Epoch 57/64
# 10762/10762 [==============================] - 36s 3ms/step - loss: 0.3161 - accuracy: 0.8791 - val_loss: 0.3157 - val_accuracy: 0.8816
# Epoch 58/64
# 10762/10762 [==============================] - 35s 3ms/step - loss: 0.3157 - accuracy: 0.8795 - val_loss: 0.3043 - val_accuracy: 0.8847
# Epoch 59/64
# 10762/10762 [==============================] - 35s 3ms/step - loss: 0.3135 - accuracy: 0.8800 - val_loss: 0.3114 - val_accuracy: 0.8828
# Epoch 60/64
# 10762/10762 [==============================] - 36s 3ms/step - loss: 0.3120 - accuracy: 0.8809 - val_loss: 0.3011 - val_accuracy: 0.8857
# Epoch 61/64
# 10762/10762 [==============================] - 20s 2ms/step - loss: 0.3099 - accuracy: 0.8817 - val_loss: 0.3186 - val_accuracy: 0.8789
# Epoch 62/64
# 10762/10762 [==============================] - 17s 2ms/step - loss: 0.3089 - accuracy: 0.8817 - val_loss: 0.3107 - val_accuracy: 0.8822
# Epoch 63/64
# 10762/10762 [==============================] - 17s 2ms/step - loss: 0.3070 - accuracy: 0.8828 - val_loss: 0.3134 - val_accuracy: 0.8791
# Epoch 64/64
# 10762/10762 [==============================] - 16s 1ms/step - loss: 0.3058 - accuracy: 0.8833 - val_loss: 0.3190 - val_accuracy: 0.8774
# 1346/1346 [==============================] - 2s 1ms/step - loss: 0.3187 - accuracy: 0.8768
# Test accuracy: 87.68%
# INFO:tensorflow:Assets written to: C:\Users\imnit\OneDrive\Desktop\EDA\acnn_model\assets
# INFO:tensorflow:Assets written to: C:\Users\imnit\OneDrive\Desktop\EDA\acnn_model\assets

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import LabelEncoder

# Load the data
test_data = pd.read_csv(r"C:\Users\imnit\OneDrive\Desktop\eda\test_data.csv")
test_points = test_data[['X', 'Y', 'Z']].values
test_labels = test_data['label'].values

# Load the trained model
model = tf.keras.models.load_model(r'C:\Users\imnit\OneDrive\Desktop\eda\acnn_model')

# Make predictions
predicted_labels_encoded = np.argmax(model.predict(test_points), axis=1)

# Convert string labels to integer labels for comparison
encoder = LabelEncoder()
true_labels_encoded = encoder.fit_transform(test_labels)
# Out:
# 1346/1346 [==============================] - 2s 1ms/step

# %%
import seaborn as sns

# Create a heatmap of the confusion matrix
conf_matrix = confusion_matrix(true_labels_encoded, predicted_labels_encoded)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix Heatmap')
plt.show()

# %%
# Calculate the correlation matrix
correlation_matrix = test_data.corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\imnit\AppData\Local\Temp\ipykernel_20308\1488549449.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = test_data.corr()

# %%
# Create box plots for each feature
plt.figure(figsize=(12, 6))
sns.boxplot(data=test_data, orient='v')
plt.title('Box Plot for Features')
plt.xticks(rotation=45)
plt.show()

# %%
# 3D visualization of test data points
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
colors = ['r', 'g', 'b', 'y', 'm']
for i, label in enumerate(encoder.classes_):
    subset = test_points[test_labels == label]
    ax.scatter(subset[:, 0], subset[:, 1], subset[:, 2], c=colors[i], label=label)

# Highlight misclassified points in black
misclassified = test_points[true_labels_encoded != predicted_labels_encoded]
ax.scatter(misclassified[:, 0], misclassified[:, 1], misclassified[:, 2], c='k', label='Misclassified', alpha=0.5)
ax.legend()
plt.show()
